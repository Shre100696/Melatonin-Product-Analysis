# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %pwd
# Out:
# 'C:\\Users\\Deshp\\Downloads'

# %%
B00K8K937I_data = pd.read_csv(r"C:\Users\Deshp\Downloads\melatonin\melatonin\Adult\B00K8K937I_Puritan'sPrideSuperStrengthRapidReleaseCapsules Melatonin.csv")

# %%
B00K8K937I_data.head()
# Out:
#          asin  ...
# 0  B00K8K937I  ...
# 1  B00K8K937I  ...
# 2  B00K8K937I  ...
# 3  B00K8K937I  ...
# 4  B00K8K937I  ...
#
# [5 rows x 22 columns]

# %%
#checking unqiue asin values
asin = np.array(B00K8K937I_data.asin)

# %%
np.unique(asin)
# Out:
# array(['B00K8K937I'], dtype=object)

# %%
print("The product title is: ", B00K8K937I_data['product_title'].unique(), "and the number of unique product title is:" , B00K8K937I_data['product_title'].nunique())
# Out:
# The product title is:  ["Puritan's Pride Super Strength Rapid Release Capsules Melatonin 120 Count (Pack of 2)"] and the number of unique product title is: 1

# %%
print('No of rows are : ', len(B00K8K937I_data.axes[0]))
print('No of columns are : ', len(B00K8K937I_data.axes[1]))
# Out:
# No of rows are :  3200
# No of columns are :  22

# %%
B00K8K937I_data.isnull().sum()
# Out:
# asin                               0
# product_title                      0
# average_rating                     0
# total_reviews                      0
# review_author                      0
# author_badge                    3184
# badge                             85
# reviewed_product_attribute         6
# reviewed_variant_asin              6
# variant_review_url                 6
# review_rating                      0
# review_date                        0
# reviewed_country                   0
# review_text                        2
# review_comment_count            3200
# review_header                      0
# no_of_people_reacted_helpful    2584
# author_profile_url                 0
# url                                0
# brand                              0
# review_url                         0
# input                              0
# dtype: int64

# %%
import seaborn as sns
plt.figure(figsize=(10,6))
sns.displot(
    data=B00K8K937I_data.isnull().melt(value_name="missing"),
    y="variable",
    hue="missing",
    multiple="fill",
    aspect=1.25
)

# %%
B07GR9WBFY_data = pd.read_csv(r"C:\Users\Deshp\Downloads\melatonin\melatonin\Adult\B07GR9WBFY_CarlyleMelatonin12mgFastDissolve180Tablets.csv")

# %%
print('No of rows are : ', len(B07GR9WBFY_data.axes[0]))
print('No of columns are : ', len(B07GR9WBFY_data.axes[1]))
# Out:
# No of rows are :  5000
# No of columns are :  22

# %%
B07GR9WBFY_data.head()
# Out:
#          asin  ...
# 0  B07GR9WBFY  ...
# 1  B07GR9WBFY  ...
# 2  B07GR9WBFY  ...
# 3  B07GR9WBFY  ...
# 4  B07GR9WBFY  ...
#
# [5 rows x 22 columns]

# %%
B07N46LTJJ_data = pd.read_csv(r"C:\Users\Deshp\Downloads\melatonin\melatonin\Adult\B07N46LTJJ_ZzzQuilPureZzzsMelatoninSleepAidGummies.csv")

# %%
B07N46LTJJ_data.head()
# Out:
#          asin  ...
# 0  B07N46LTJJ  ...
# 1  B07N46LTJJ  ...
# 2  B07N46LTJJ  ...
# 3  B07N46LTJJ  ...
# 4  B07N46LTJJ  ...
#
# [5 rows x 22 columns]

# %%
print('No of rows are : ', len(B07N46LTJJ_data.axes[0]))
print('No of columns are : ', len(B07N46LTJJ_data.axes[1]))
# Out:
# No of rows are :  1300
# No of columns are :  22

# %%
B07PF1SN5B_data = pd.read_csv(r"C:\Users\Deshp\Downloads\melatonin\melatonin\Adult\B07PF1SN5B_vitafusionMaxStrengthMelatoninGummySupplements.csv")

# %%
print('No of rows are : ', len(B07PF1SN5B_data.axes[0]))
print('No of columns are : ', len(B07PF1SN5B_data.axes[1]))
# Out:
# No of rows are :  1950
# No of columns are :  22

# %%
B07PF1SN5B_data.head()
# Out:
#          asin  ...
# 0  B07PF1SN5B  ...
# 1  B07PF1SN5B  ...
# 2  B07PF1SN5B  ...
# 3  B07PF1SN5B  ...
# 4  B07PF1SN5B  ...
#
# [5 rows x 22 columns]

# %%
B08CGYFB2Q_data = pd.read_csv(r"C:\Users\Deshp\Downloads\melatonin\melatonin\Adult\B08CGYFB2Q_VitamaticMelatonin20mgTablets.csv")

# %%
B08CGYFB2Q_data.head()
# Out:
#          asin  ...
# 0  B08CGYFB2Q  ...
# 1  B08CGYFB2Q  ...
# 2  B08CGYFB2Q  ...
# 3  B08CGYFB2Q  ...
# 4  B08CGYFB2Q  ...
#
# [5 rows x 22 columns]

# %%
print('No of rows are : ', len(B08CGYFB2Q_data.axes[0]))
print('No of columns are : ', len(B08CGYFB2Q_data.axes[1]))
# Out:
# No of rows are :  1000
# No of columns are :  22

# %%
B079TD7HG2_data = pd.read_csv(r"C:\Users\Deshp\Downloads\melatonin\melatonin\Adult\B079TD7HG2_NatrolMelatoninSleepAidGummy.csv")

# %%
B079TD7HG2_data.head()
# Out:
#          asin  ...
# 0  B079TD7HG2  ...
# 1  B079TD7HG2  ...
# 2  B079TD7HG2  ...
# 3  B079TD7HG2  ...
# 4  B079TD7HG2  ...
#
# [5 rows x 22 columns]

# %%
print('No of rows are : ', len(B079TD7HG2_data.axes[0]))
print('No of columns are : ', len(B079TD7HG2_data.axes[1]))
# Out:
# No of rows are :  2700
# No of columns are :  22

# %%
B08451719W_data = pd.read_csv(r"C:\Users\Deshp\Downloads\melatonin\melatonin\Adult\B08451719W_CarlyleMelatonin12mgFastDissolve300Tablets.csv")

# %%
B08451719W_data.head()
# Out:
#          asin  ...
# 0  B08451719W  ...
# 1  B08451719W  ...
# 2  B08451719W  ...
# 3  B08451719W  ...
# 4  B08451719W  ...
#
# [5 rows x 22 columns]

# %%
print('No of rows are : ', len(B08451719W_data.axes[0]))
print('No of columns are : ', len(B08451719W_data.axes[1]))
# Out:
# No of rows are :  760
# No of columns are :  22

# %%
#creating a dataframe by forming a lits of dataframes
dataframes =[B08451719W_data,B079TD7HG2_data,B08CGYFB2Q_data,B07PF1SN5B_data,B07N46LTJJ_data,B07GR9WBFY_data,B00K8K937I_data]

# %%
#checking if all the the adult files have same column names
np.all([sorted(dataframes[0].columns) == sorted(i.columns) for i in dataframes])
# Out:
# True

# %%
adults_final_data = pd.concat([B08451719W_data,B079TD7HG2_data,B08CGYFB2Q_data,B07PF1SN5B_data,B07N46LTJJ_data,B07GR9WBFY_data,B00K8K937I_data], axis=0)

# %%
adults_final_data.head()
# Out:
#          asin  ...
# 0  B08451719W  ...
# 1  B08451719W  ...
# 2  B08451719W  ...
# 3  B08451719W  ...
# 4  B08451719W  ...
#
# [5 rows x 22 columns]

# %%
print('No of rows in final adultd dataset are : ', len(adults_final_data.axes[0]))
print('No of columns in final adultd dataset are : ', len(adults_final_data.axes[1]))
# Out:
# No of rows in final adultd dataset are :  15910
# No of columns in final adultd dataset are :  22

# %%
adults_final_data.isnull().sum()
# Out:
# asin                                0
# product_title                       0
# average_rating                      0
# total_reviews                       0
# review_author                       0
# author_badge                    15808
# badge                             309
# reviewed_product_attribute       2095
# reviewed_variant_asin            2095
# variant_review_url               2095
# review_rating                       0
# review_date                         0
# reviewed_country                    0
# review_text                        24
# review_comment_count            15910
# review_header                       2
# no_of_people_reacted_helpful    13149
# author_profile_url                  0
# url                                 0
# brand                               0
# review_url                          0
# input                               0
# dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.displot(
    data=adults_final_data.isnull().melt(value_name="missing"),
    y="variable",
    hue="missing",
    multiple="fill",
    aspect=1.25
)

# %%
adults_final_data['asin_input'] = (adults_final_data['asin'] == adults_final_data['input'])

# %%
adults_final_data.columns
# Out:
# Index(['asin', 'product_title', 'average_rating', 'total_reviews',
#        'review_author', 'author_badge', 'badge', 'reviewed_product_attribute',
#        'reviewed_variant_asin', 'variant_review_url', 'review_rating',
#        'review_date', 'reviewed_country', 'review_text',
#        'review_comment_count', 'review_header', 'no_of_people_reacted_helpful',
#        'author_profile_url', 'url', 'brand', 'review_url', 'input',
#        'asin_input'],
#       dtype='object')

# %%
adults_final_data['asin_input'].unique()
# Out:
# array([ True])

# %%
# input and asin values are same so we can drop input column from dataset and review_comment_count is NA in dataset so we can drop this column as well

# %%
adults_final_data.drop(['review_comment_count','input','asin_input'], axis=1, inplace=True)

# %%
adults_final_data['Type'] = 'Adults'
adults_final_data
# Out:
#             asin  ...
# 0     B08451719W  ...
# 1     B08451719W  ...
# 2     B08451719W  ...
# 3     B08451719W  ...
# 4     B08451719W  ...
# ...          ...  ...
# 3195  B00K8K937I  ...
# 3196  B00K8K937I  ...
# 3197  B00K8K937I  ...
# 3198  B00K8K937I  ...
# 3199  B00K8K937I  ...
#
# [15910 rows x 21 columns]

# %%
# What are the unique product title in the adults medication


#setting the output window
pd.set_option('display.max_columns',1)
pd.DataFrame(adults_final_data['product_title'].unique(), columns = ['product_title'])
# Out:
#                                        product_title
# 0  Carlyle Melatonin 12 mg Fast Dissolve 300 Tabl...
# 1  Natrol Melatonin Sleep Aid Gummy, Fall Asleep ...
# 2  Vitamatic Melatonin 20mg Tablets | Vegetarian,...
# 3  vitafusion Max Strength Melatonin Gummy Supple...
# 4  ZzzQuil Pure Zzzs Melatonin Sleep Aid Gummies,...
# 5  Carlyle Melatonin 12 mg Fast Dissolve 180 Tabl...
# 6  Puritan's Pride Super Strength Rapid Release C...

# %%
B01MAWIGWT_data = pd.read_csv("C:/Users/dpsmv/Downloads/melatonin/melatonin/Kids/B01MAWIGWT_Zarbee'sKids1mgMelatoninGummy.csv")
pd.set_option('display.max_columns',22)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 B01MAWIGWT_data = pd.read_csv("C:/Users/dpsmv/Downloads/melatonin/melatonin/Kids/B01MAWIGWT_Zarbee'sKids1mgMelatoninGummy.csv")
#       2 pd.set_option('display.max_columns',22)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
B01MAWIGWT_data.head()
# Out:
#          asin                                      product_title  \
# 0  B01MAWIGWT  Zarbee's Kids 1mg Melatonin Gummy, Drug-Free &...
# 1  B01MAWIGWT  Zarbee's Kids 1mg Melatonin Gummy, Drug-Free &...
# 2  B01MAWIGWT  Zarbee's Kids 1mg Melatonin Gummy, Drug-Free &...
# 3  B01MAWIGWT  Zarbee's Kids 1mg Melatonin Gummy, Drug-Free &...
# 4  B01MAWIGWT  Zarbee's Kids 1mg Melatonin Gummy, Drug-Free &...
#
#    average_rating  total_reviews     review_author author_badge  \
# 0             4.7           3256  Christina Majors          NaN
# 1             4.7           3256   Amazon Customer          NaN
# 2             4.7           3256              Juan          NaN
# 3             4.7           3256   Amazon Customer          NaN
# 4             4.7           3256         Darren S.          NaN
#
#                badge                   reviewed_product_attribute  \
# 0  Verified Purchase  Style: Kids Bedtime Melatonin Gummies, 50ct
# ...

# %%
B01MAWIGWT_data.shape
# Out:
# (3250, 22)

# %%
B01MAWIGWT_data.columns
# Out:
# Index(['asin', 'product_title', 'average_rating', 'total_reviews',
#        'review_author', 'author_badge', 'badge', 'reviewed_product_attribute',
#        'reviewed_variant_asin', 'variant_review_url', 'review_rating',
#        'review_date', 'reviewed_country', 'review_text',
#        'review_comment_count', 'review_header', 'no_of_people_reacted_helpful',
#        'author_profile_url', 'url', 'brand', 'review_url', 'input'],
#       dtype='object')

# %%
B07VMJMZNP_data = pd.read_csv("C:/Users/dpsmv/Downloads/melatonin/melatonin/Kids/B07VMJMZNP_NatrolKidsMelatoninGummy.csv")

# %%
B07VMJMZNP_data.head()
# Out:
#          asin                                      product_title  \
# 0  B07VMJMZNP  Natrol Kids Melatonin Gummy, 1mg, Sleep Aid Su...
# 1  B07VMJMZNP  Natrol Kids Melatonin Gummy, 1mg, Sleep Aid Su...
# 2  B07VMJMZNP  Natrol Kids Melatonin Gummy, 1mg, Sleep Aid Su...
# 3  B07VMJMZNP  Natrol Kids Melatonin Gummy, 1mg, Sleep Aid Su...
# 4  B07VMJMZNP  Natrol Kids Melatonin Gummy, 1mg, Sleep Aid Su...
#
#    average_rating  total_reviews    review_author author_badge  \
# 0             4.8            891          scarlet          NaN
# 1             4.8            891           Dallin          NaN
# 2             4.8            891           Plinio          NaN
# 3             4.8            891    L. K. Kendall          NaN
# 4             4.8            891  Amazon Customer          NaN
#
#                badge reviewed_product_attribute reviewed_variant_asin  \
# 0  Verified Purchase           Style: Sleep Aid            B07VMJMZNP
# ...

# %%
B07VMJMZNP_data.shape
# Out:
# (890, 22)

# %%
B07VMJMZNP_data.columns
# Out:
# Index(['asin', 'product_title', 'average_rating', 'total_reviews',
#        'review_author', 'author_badge', 'badge', 'reviewed_product_attribute',
#        'reviewed_variant_asin', 'variant_review_url', 'review_rating',
#        'review_date', 'reviewed_country', 'review_text',
#        'review_comment_count', 'review_header', 'no_of_people_reacted_helpful',
#        'author_profile_url', 'url', 'brand', 'review_url', 'input'],
#       dtype='object')

# %%
kids_final_data = pd.concat([B01MAWIGWT_data,B07VMJMZNP_data], axis=0)
pd.set_option('display.max_columns',22)
kids_final_data
# Out:
#            asin                                      product_title  \
# 0    B01MAWIGWT  Zarbee's Kids 1mg Melatonin Gummy, Drug-Free &...
# 1    B01MAWIGWT  Zarbee's Kids 1mg Melatonin Gummy, Drug-Free &...
# 2    B01MAWIGWT  Zarbee's Kids 1mg Melatonin Gummy, Drug-Free &...
# 3    B01MAWIGWT  Zarbee's Kids 1mg Melatonin Gummy, Drug-Free &...
# 4    B01MAWIGWT  Zarbee's Kids 1mg Melatonin Gummy, Drug-Free &...
# ..          ...                                                ...
# 885  B07VMJMZNP  Natrol Kids Melatonin Gummy, 1mg, Sleep Aid Su...
# 886  B07VMJMZNP  Natrol Kids Melatonin Gummy, 1mg, Sleep Aid Su...
# 887  B07VMJMZNP  Natrol Kids Melatonin Gummy, 1mg, Sleep Aid Su...
# 888  B07VMJMZNP  Natrol Kids Melatonin Gummy, 1mg, Sleep Aid Su...
# 889  B07VMJMZNP  Natrol Kids Melatonin Gummy, 1mg, Sleep Aid Su...
#
#      average_rating  total_reviews     review_author author_badge  \
# 0               4.7           3256  Christina Majors          NaN
# ...

# %%
kids_final_data.isnull().sum()
# Out:
# asin                               0
# product_title                      0
# average_rating                     0
# total_reviews                      0
# review_author                      0
# author_badge                    4126
# badge                            155
# reviewed_product_attribute         2
# reviewed_variant_asin              2
# variant_review_url                 2
# review_rating                      0
# review_date                        0
# reviewed_country                   0
# review_text                        3
# review_comment_count            4140
# review_header                      0
# no_of_people_reacted_helpful    3549
# author_profile_url                 0
# url                                0
# brand                              0
# review_url                         0
# input                              0
# dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.displot(
    data=kids_final_data.isnull().melt(value_name="missing"),
    y="variable",
    hue="missing",
    multiple="fill",
    aspect=1.25
)

# %%
kids_final_data['asin_input'] = (kids_final_data['asin'] == kids_final_data['input'])

# %%
kids_final_data['asin_input'].unique()
# Out:
# array([ True])

# %%
kids_final_data.drop(['review_comment_count','input','asin_input'], axis=1, inplace=True)

# %%
kids_final_data['Type']='Kids'

# %%
kids_final_data.head()
# Out:
#          asin                                      product_title  \
# 0  B01MAWIGWT  Zarbee's Kids 1mg Melatonin Gummy, Drug-Free &...
# 1  B01MAWIGWT  Zarbee's Kids 1mg Melatonin Gummy, Drug-Free &...
# 2  B01MAWIGWT  Zarbee's Kids 1mg Melatonin Gummy, Drug-Free &...
# 3  B01MAWIGWT  Zarbee's Kids 1mg Melatonin Gummy, Drug-Free &...
# 4  B01MAWIGWT  Zarbee's Kids 1mg Melatonin Gummy, Drug-Free &...
#
#    average_rating  total_reviews     review_author author_badge  \
# 0             4.7           3256  Christina Majors          NaN
# 1             4.7           3256   Amazon Customer          NaN
# 2             4.7           3256              Juan          NaN
# 3             4.7           3256   Amazon Customer          NaN
# 4             4.7           3256         Darren S.          NaN
#
#                badge                   reviewed_product_attribute  \
# 0  Verified Purchase  Style: Kids Bedtime Melatonin Gummies, 50ct
# ...

# %%
kids_final_data.shape
# Out:
# (4140, 21)

# %%
adults_final_data.shape
# Out:
# (15910, 21)

# %%
melatonin_dataset = pd.concat([adults_final_data,kids_final_data])

# %%
melatonin_dataset.head()
# Out:
#          asin                                      product_title  \
# 0  B08451719W  Carlyle Melatonin 12 mg Fast Dissolve 300 Tabl...
# 1  B08451719W  Carlyle Melatonin 12 mg Fast Dissolve 300 Tabl...
# 2  B08451719W  Carlyle Melatonin 12 mg Fast Dissolve 300 Tabl...
# 3  B08451719W  Carlyle Melatonin 12 mg Fast Dissolve 300 Tabl...
# 4  B08451719W  Carlyle Melatonin 12 mg Fast Dissolve 300 Tabl...
#
#    average_rating  total_reviews     review_author author_badge  \
# 0             4.7            768               Jay          NaN
# 1             4.7            768            Esc Go          NaN
# 2             4.7            768       Dawn Wilson          NaN
# 3             4.7            768  Margaret hodgson          NaN
# 4             4.7            768        Troy Acton          NaN
#
#                badge reviewed_product_attribute reviewed_variant_asin  \
# 0  Verified Purchase                        NaN                   NaN
# ...

# %%
print("The final dataset consists of rows - ",len(melatonin_dataset.axes[0]),"and columns is - ", len(melatonin_dataset.axes[1]))
# Out:
# The final dataset consists of rows -  20050 and columns is -  21

# %% [markdown]
# # Data cleansing

# %%
# data types of fields
melatonin_dataset.dtypes
# Out:
# asin                             object
# product_title                    object
# average_rating                  float64
# total_reviews                     int64
# review_author                    object
# author_badge                     object
# badge                            object
# reviewed_product_attribute       object
# reviewed_variant_asin            object
# variant_review_url               object
# review_rating                   float64
# review_date                      object
# reviewed_country                 object
# review_text                      object
# review_header                    object
# no_of_people_reacted_helpful     object
# author_profile_url               object
# url                              object
# brand                            object
# review_url                       object
# Type                             object
# dtype: object

# %%
# converting review date field object to date data type
melatonin_dataset['review_date'] = pd.to_datetime(melatonin_dataset['review_date'])

# %%
melatonin_dataset.dtypes
# Out:
# asin                                    object
# product_title                           object
# average_rating                         float64
# total_reviews                            int64
# review_author                           object
# author_badge                            object
# badge                                   object
# reviewed_product_attribute              object
# reviewed_variant_asin                   object
# variant_review_url                      object
# review_rating                          float64
# review_date                     datetime64[ns]
# reviewed_country                        object
# review_text                             object
# review_header                           object
# no_of_people_reacted_helpful            object
# author_profile_url                      object
# url                                     object
# brand                                   object
# review_url                              object
# ...

# %%
melatonin_dataset.head()
# Out:
#          asin                                      product_title  \
# 0  B08451719W  Carlyle Melatonin 12 mg Fast Dissolve 300 Tabl...
# 1  B08451719W  Carlyle Melatonin 12 mg Fast Dissolve 300 Tabl...
# 2  B08451719W  Carlyle Melatonin 12 mg Fast Dissolve 300 Tabl...
# 3  B08451719W  Carlyle Melatonin 12 mg Fast Dissolve 300 Tabl...
# 4  B08451719W  Carlyle Melatonin 12 mg Fast Dissolve 300 Tabl...
#
#    average_rating  total_reviews     review_author author_badge  \
# 0             4.7            768               Jay          NaN
# 1             4.7            768            Esc Go          NaN
# 2             4.7            768       Dawn Wilson          NaN
# 3             4.7            768  Margaret hodgson          NaN
# 4             4.7            768        Troy Acton          NaN
#
#                badge reviewed_product_attribute reviewed_variant_asin  \
# 0  Verified Purchase                        NaN                   NaN
# ...

# %%
melatonin_dataset['product_title'].nunique()
# Out:
# 9

# %%
melatonin_dataset['asin'].nunique()
# Out:
# 9

# %%
#no of unique asin
product_title_asin = melatonin_dataset[['asin','product_title','Type']]

# %%
pd.set_option('display.max_columns',3)
df2 = product_title_asin.drop_duplicates()
df2
# Out:
#          asin                                      product_title    Type
# 0  B08451719W  Carlyle Melatonin 12 mg Fast Dissolve 300 Tabl...  Adults
# 0  B079TD7HG2  Natrol Melatonin Sleep Aid Gummy, Fall Asleep ...  Adults
# 0  B08CGYFB2Q  Vitamatic Melatonin 20mg Tablets | Vegetarian,...  Adults
# 0  B07PF1SN5B  vitafusion Max Strength Melatonin Gummy Supple...  Adults
# 0  B07N46LTJJ  ZzzQuil Pure Zzzs Melatonin Sleep Aid Gummies,...  Adults
# 0  B07GR9WBFY  Carlyle Melatonin 12 mg Fast Dissolve 180 Tabl...  Adults
# 0  B00K8K937I  Puritan's Pride Super Strength Rapid Release C...  Adults
# 0  B01MAWIGWT  Zarbee's Kids 1mg Melatonin Gummy, Drug-Free &...    Kids
# 0  B07VMJMZNP  Natrol Kids Melatonin Gummy, 1mg, Sleep Aid Su...    Kids

# %%
product_title_asin.groupby('Type')['asin'].nunique()
# Out:
# Type
# Adults    7
# Kids      2
# Name: asin, dtype: int64

# %%
data = {'Type':['Adults','Kids'], 'count':[7,2]}

# %%
adults_kids = pd.DataFrame(data)

# %%
plt.bar(adults_kids['Type'],adults_kids['count'])
# Out:
# <BarContainer object of 2 artists>

# %%
melatonin_dataset.dropna().describe()
# Out:
#        average_rating  total_reviews  review_rating
# count       24.000000      24.000000      24.000000
# mean         4.587500    4416.125000       4.541667
# std          0.085019    1948.659167       1.178767
# min          4.500000     891.000000       1.000000
# 25%          4.500000    2749.000000       5.000000
# 50%          4.600000    5151.000000       5.000000
# 75%          4.600000    6594.000000       5.000000
# max          4.800000    6594.000000       5.000000

# %%
#Iteration over asin to find out how many asin products are available
for (asin, group) in melatonin_dataset.groupby('asin'):
    print("{0:30s} shape={1}".format(asin, group.shape))
# Out:
# B00K8K937I                     shape=(3200, 21)
# B01MAWIGWT                     shape=(3250, 21)
# B079TD7HG2                     shape=(2700, 21)
# B07GR9WBFY                     shape=(5000, 21)
# B07N46LTJJ                     shape=(1300, 21)
# B07PF1SN5B                     shape=(1950, 21)
# B07VMJMZNP                     shape=(890, 21)
# B08451719W                     shape=(760, 21)
# B08CGYFB2Q                     shape=(1000, 21)

# %%
melatonin_dataset.columns
# Out:
# Index(['asin', 'product_title', 'average_rating', 'total_reviews',
#        'review_author', 'author_badge', 'badge', 'reviewed_product_attribute',
#        'reviewed_variant_asin', 'variant_review_url', 'review_rating',
#        'review_date', 'reviewed_country', 'review_text', 'review_header',
#        'no_of_people_reacted_helpful', 'author_profile_url', 'url', 'brand',
#        'review_url', 'Type'],
#       dtype='object')

# %%
min_rating_for_product_title = melatonin_dataset.groupby('product_title').aggregate({'average_rating':'min'})
min_rating_for_product_title['average_rating']
# Out:
# product_title
# Carlyle Melatonin 12 mg Fast Dissolve 180 Tablets | Drug Free | Natural Berry Flavor | Vegetarian, Non-GMO, Gluten Free                                                          4.5
# Carlyle Melatonin 12 mg Fast Dissolve 300 Tablets | Drug Free | Natural Berry Flavor | Vegetarian, Non-GMO, Gluten Free                                                          4.7
# Natrol Kids Melatonin Gummy, 1mg, Sleep Aid Supplement for Children, Ages 4 and up, 90 Berry Flavored Gummies                                                                    4.8
# Natrol Melatonin Sleep Aid Gummy, Fall Asleep Faster, Stay Asleep Longer, 2 Gummies Per Serving, Drug Free and Gelatin Free, 10mg, 90 Strawberry Flavored Gummies                4.7
# Puritan's Pride Super Strength Rapid Release Capsules Melatonin 120 Count (Pack of 2)                                                                                            4.6
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.barplot(y=min_rating_for_product_title.index, x='average_rating', data=min_rating_for_product_title)
# Out:
# <AxesSubplot:xlabel='average_rating', ylabel='product_title'>

# %%
melatonin_dataset['product_title'].unique()
# Out:
# array(['Carlyle Melatonin 12 mg Fast Dissolve 300 Tablets | Drug Free | Natural Berry Flavor | Vegetarian, Non-GMO, Gluten Free',
#        'Natrol Melatonin Sleep Aid Gummy, Fall Asleep Faster, Stay Asleep Longer, 2 Gummies Per Serving, Drug Free and Gelatin Free, 10mg, 90 Strawberry Flavored Gummies',
#        'Vitamatic Melatonin 20mg Tablets | Vegetarian, Non-GMO, Gluten Free | HIGH Potency 20 MG | Natural Berry Flavor |',
#        'vitafusion Max Strength Melatonin Gummy Supplements, Strawberry Flavored, 10 mg Melatonin Sleep Supplements, America’s Number 1 Gummy Vitamin Brand, 50 Day Supply, 100 Count',
#        'ZzzQuil Pure Zzzs Melatonin Sleep Aid Gummies, Helps You Fall Asleep Naturally, Wildberry Vanilla Flavor, Chamomile Lavender & Valerian Root, 1mg per Gummy, 72 Count',
#        'Carlyle Melatonin 12 mg Fast Dissolve 180 Tablets | Drug Free | Natural Berry Flavor | Vegetarian, Non-GMO, Gluten Free',
# ...

# %%
import re
import pandas as pd

# create an example DataFrame
df = pd.DataFrame(product_title_asin['product_title'].unique(), columns=['product_title'])

# define a regular expression to extract mg values
mg_regex = re.compile(r'\d+\s?mg|\d+mg')

# define a function to extract mg values from a product name
def extract_mg_value(text):
    mg_match = mg_regex.search(text)
    if mg_match:
        mg_value = mg_match.group().strip()
        return mg_value
    else:
        return None

# apply the function to the product_name column and append the results as a new column
df['mg_value'] = df['product_title'].apply(lambda x: extract_mg_value(x))

# print the updated DataFrame
print(df)
# Out:
#                                        product_title mg_value
# 0  Carlyle Melatonin 12 mg Fast Dissolve 300 Tabl...    12 mg
# 1  Natrol Melatonin Sleep Aid Gummy, Fall Asleep ...     10mg
# 2  Vitamatic Melatonin 20mg Tablets | Vegetarian,...     20mg
# 3  vitafusion Max Strength Melatonin Gummy Supple...    10 mg
# 4  ZzzQuil Pure Zzzs Melatonin Sleep Aid Gummies,...      1mg
# 5  Carlyle Melatonin 12 mg Fast Dissolve 180 Tabl...    12 mg
# 6  Puritan's Pride Super Strength Rapid Release C...     None
# 7  Zarbee's Kids 1mg Melatonin Gummy, Drug-Free &...      1mg
# 8  Natrol Kids Melatonin Gummy, 1mg, Sleep Aid Su...      1mg

# %%
merged_df = pd.merge(df, df2, on='product_title')
pd.set_option('display.max_columns',4)
merged_df

merged_df['mg_value'] = df['mg_value'].str.extract(r'(\d+)').fillna(0).astype('int')

merged_df
# Out:
#                                        product_title  mg_value        asin  \
# 0  Carlyle Melatonin 12 mg Fast Dissolve 300 Tabl...        12  B08451719W
# 1  Natrol Melatonin Sleep Aid Gummy, Fall Asleep ...        10  B079TD7HG2
# 2  Vitamatic Melatonin 20mg Tablets | Vegetarian,...        20  B08CGYFB2Q
# 3  vitafusion Max Strength Melatonin Gummy Supple...        10  B07PF1SN5B
# 4  ZzzQuil Pure Zzzs Melatonin Sleep Aid Gummies,...         1  B07N46LTJJ
# 5  Carlyle Melatonin 12 mg Fast Dissolve 180 Tabl...        12  B07GR9WBFY
# 6  Puritan's Pride Super Strength Rapid Release C...         0  B00K8K937I
# 7  Zarbee's Kids 1mg Melatonin Gummy, Drug-Free &...         1  B01MAWIGWT
# 8  Natrol Kids Melatonin Gummy, 1mg, Sleep Aid Su...         1  B07VMJMZNP
#
#      Type
# 0  Adults
# 1  Adults
# 2  Adults
# 3  Adults
# 4  Adults
# 5  Adults
# 6  Adults
# 7    Kids
# 8    Kids

# %%
filtered_df = merged_df[merged_df['Type']=='Adults']
filtered_df
kids_filtered_df = merged_df[merged_df['Type']=='Kids']
kids_filtered_df
plt.barh(filtered_df['product_title'],filtered_df['mg_value'], color='green')
plt.barh(kids_filtered_df['product_title'],kids_filtered_df['mg_value'], color='red')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 filtered_df = merged_df[merged_df['Type']=='Adults']
#       2 filtered_df
#       3 kids_filtered_df = merged_df[merged_df['Type']=='Kids']
#
# NameError: name 'merged_df' is not defined

# %%
melatonin_dataset['reviewed_product_attribute'].unique()
# Out:
# array([nan, 'Style: 10mg | Size: 90 Count (Pack of 1)',
#        'Style: 10mg | Size: 140 Count (Pack of 1)',
#        'Style: 5mg | Size: 90 Count (Pack of 1)',
#        'Size: 120 Count (Pack of 2)', 'Size: 120 Count (Pack of 1)',
#        'Size: 120 Count (Pack of 3)',
#        'Size: 120 Count (Pack of 1) | Style: Extra Strength',
#        'Size: 100 Count (Pack of 1) | Style: Max Strength',
#        'Size: 50 Count (Pack of 1) | Style: Kids',
#        'Size: 140 Count (Pack of 1) | Style: Regular Strength',
#        'Size: 180 Count (Pack of 1)', 'Size: 60 Count (Pack of 1)',
#        'Style: Kids Bedtime Melatonin Gummies, 50ct', 'Style: Sleep Aid'],
#       dtype=object)

# %%
melatonin_dataset.shape
# Out:
# (20050, 21)

# %%
pd.set_option('display.max_columns',21)
melatonin_dataset.head()
# Out:
#          asin                                      product_title  \
# 0  B08451719W  Carlyle Melatonin 12 mg Fast Dissolve 300 Tabl...
# 1  B08451719W  Carlyle Melatonin 12 mg Fast Dissolve 300 Tabl...
# 2  B08451719W  Carlyle Melatonin 12 mg Fast Dissolve 300 Tabl...
# 3  B08451719W  Carlyle Melatonin 12 mg Fast Dissolve 300 Tabl...
# 4  B08451719W  Carlyle Melatonin 12 mg Fast Dissolve 300 Tabl...
#
#    average_rating  total_reviews     review_author author_badge  \
# 0             4.7            768               Jay          NaN
# 1             4.7            768            Esc Go          NaN
# 2             4.7            768       Dawn Wilson          NaN
# 3             4.7            768  Margaret hodgson          NaN
# 4             4.7            768        Troy Acton          NaN
#
#                badge reviewed_product_attribute reviewed_variant_asin  \
# 0  Verified Purchase                        NaN                   NaN
# ...

# %%
pd.set_option('display.max_columns',1)
melatonin_dataset['review_author'].nunique()
# Out:
# 16016

# %%
pd.set_option('display.max_columns',21)
filtered_df = melatonin_dataset[melatonin_dataset['review_author'] == '...']
filtered_df
# Out:
#             asin                                      product_title  \
# 1053  B07PF1SN5B  vitafusion Max Strength Melatonin Gummy Supple...
# 1601  B01MAWIGWT  Zarbee's Kids 1mg Melatonin Gummy, Drug-Free &...
#
#       average_rating  total_reviews review_author author_badge  \
# 1053             4.6           5151           ...          NaN
# 1601             4.7           3256           ...          NaN
#
#                   badge                         reviewed_product_attribute  \
# 1053  Verified Purchase  Size: 120 Count (Pack of 1) | Style: Extra Str...
# 1601  Verified Purchase        Style: Kids Bedtime Melatonin Gummies, 50ct
#
#      reviewed_variant_asin                                 variant_review_url  \
# 1053            B00OJMZSWU  https://www.amazon.com/Vitafusion-Strength-Mel...
# 1601            B01MAWIGWT  https://www.amazon.com/Zarbees-Naturals-Childr...
#
#       review_rating review_date reviewed_country  \
# 1053            4.0  2022-08-29   United States
# ...

# %%
melatonin_dataset['reviewed_product_attribute'].unique()
# Out:
# array([nan, 'Style: 10mg | Size: 90 Count (Pack of 1)',
#        'Style: 10mg | Size: 140 Count (Pack of 1)',
#        'Style: 5mg | Size: 90 Count (Pack of 1)',
#        'Size: 120 Count (Pack of 2)', 'Size: 120 Count (Pack of 1)',
#        'Size: 120 Count (Pack of 3)',
#        'Size: 120 Count (Pack of 1) | Style: Extra Strength',
#        'Size: 100 Count (Pack of 1) | Style: Max Strength',
#        'Size: 50 Count (Pack of 1) | Style: Kids',
#        'Size: 140 Count (Pack of 1) | Style: Regular Strength',
#        'Size: 180 Count (Pack of 1)', 'Size: 60 Count (Pack of 1)',
#        'Style: Kids Bedtime Melatonin Gummies, 50ct', 'Style: Sleep Aid'],
#       dtype=object)

# %%
pd.set_option('display.max_columns',1)
merged_df['product_title']
# Out:
# 0    Carlyle Melatonin 12 mg Fast Dissolve 300 Tabl...
# 1    Natrol Melatonin Sleep Aid Gummy, Fall Asleep ...
# 2    Vitamatic Melatonin 20mg Tablets | Vegetarian,...
# 3    vitafusion Max Strength Melatonin Gummy Supple...
# 4    ZzzQuil Pure Zzzs Melatonin Sleep Aid Gummies,...
# 5    Carlyle Melatonin 12 mg Fast Dissolve 180 Tabl...
# 6    Puritan's Pride Super Strength Rapid Release C...
# 7    Zarbee's Kids 1mg Melatonin Gummy, Drug-Free &...
# 8    Natrol Kids Melatonin Gummy, 1mg, Sleep Aid Su...
# Name: product_title, dtype: object

# %%
# we can conclude that the data sets were only colleected from united states
melatonin_dataset['reviewed_country'].unique()
# Out:
# array(['United States ', 'United States'], dtype=object)

# %%
melatonin_dataset['review_year']= melatonin_dataset['review_date'].dt.year

# %%
pd.set_option('display.max_columns',22)
melatonin_dataset.head()
# Out:
#          asin                                      product_title  \
# 0  B08451719W  Carlyle Melatonin 12 mg Fast Dissolve 300 Tabl...
# 1  B08451719W  Carlyle Melatonin 12 mg Fast Dissolve 300 Tabl...
# 2  B08451719W  Carlyle Melatonin 12 mg Fast Dissolve 300 Tabl...
# 3  B08451719W  Carlyle Melatonin 12 mg Fast Dissolve 300 Tabl...
# 4  B08451719W  Carlyle Melatonin 12 mg Fast Dissolve 300 Tabl...
#
#    average_rating  total_reviews     review_author author_badge  \
# 0             4.7            768               Jay          NaN
# 1             4.7            768            Esc Go          NaN
# 2             4.7            768       Dawn Wilson          NaN
# 3             4.7            768  Margaret hodgson          NaN
# 4             4.7            768        Troy Acton          NaN
#
#                badge reviewed_product_attribute reviewed_variant_asin  \
# 0  Verified Purchase                        NaN                   NaN
# ...

# %%
total_reviews_based_on_year = melatonin_dataset.groupby(by = ['review_year'])['total_reviews'].sum()
total_reviews_based_on_year
# Out:
# review_year
# 2012        9819
# 2013       62187
# 2014      402579
# 2015     1024986
# 2016      638559
# 2017     1460522
# 2018     3523316
# 2019    12353307
# 2020    21243338
# 2021    21375472
# 2022    13182279
# 2023      336456
# Name: total_reviews, dtype: int64

# %%
plt.plot(total_reviews_based_on_year)
